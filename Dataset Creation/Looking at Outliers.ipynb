# %% [markdown]
# # Exploratory Analysis
# ## Load in Packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load in Dataframe

# %%
master_mood = pd.read_csv('master_mood.csv')
master_mood
# Out:
#      Unnamed: 0                                     Name  \
# 0             0                          I Ain't Worried
# 1             1                                As It Was
# 2             2  Left and Right (Feat. Jung Kook of BTS)
# 3             3                                     SNAP
# 4             4                                  Sunroof
# ..          ...                                      ...
# 946         955                                      Oh!
# 947         956                       God Complex (Mojo)
# 948         957                                  I EXIST
# 949         958        Apartment Complex on the Eastside
# 950         959                      Black Roller Coming
#
#                    Track_ID  \
# 0    4h9wh7iOZ0GGn8QVp4RAOB
# 1    4LRPiXqCikLlN15c3yImP7
# 2    0mBP9X2gPCuapvpZ7TGDk3
# 3    76OGwb5RA9h4FxQPT33ekc
# 4    4h4QlmocP3IuwYEj2j14p8
# ..                      ...
# 946  4e72LGraX8sW5iztJvS5fo
# 947  1B3ouXA9iRkqY1ywvZbzZ5
# ...

# %% [markdown]
# ## Fix Index

# %%
master_mood1 = master_mood.reset_index()
master_mood1
# Out:
#      index  Unnamed: 0                                     Name  \
# 0        0           0                          I Ain't Worried
# 1        1           1                                As It Was
# 2        2           2  Left and Right (Feat. Jung Kook of BTS)
# 3        3           3                                     SNAP
# 4        4           4                                  Sunroof
# ..     ...         ...                                      ...
# 946    946         955                                      Oh!
# 947    947         956                       God Complex (Mojo)
# 948    948         957                                  I EXIST
# 949    949         958        Apartment Complex on the Eastside
# 950    950         959                      Black Roller Coming
#
#                    Track_ID  \
# 0    4h9wh7iOZ0GGn8QVp4RAOB
# 1    4LRPiXqCikLlN15c3yImP7
# 2    0mBP9X2gPCuapvpZ7TGDk3
# 3    76OGwb5RA9h4FxQPT33ekc
# 4    4h4QlmocP3IuwYEj2j14p8
# ...

# %% [markdown]
# ## Removing Unnecessary Columns

# %%
master_mood2 = master_mood1.drop(['Unnamed: 0', 'index'], axis = 1)
master_mood2
# Out:
#                                         Name                Track_ID  \
# 0                            I Ain't Worried  4h9wh7iOZ0GGn8QVp4RAOB
# 1                                  As It Was  4LRPiXqCikLlN15c3yImP7
# 2    Left and Right (Feat. Jung Kook of BTS)  0mBP9X2gPCuapvpZ7TGDk3
# 3                                       SNAP  76OGwb5RA9h4FxQPT33ekc
# 4                                    Sunroof  4h4QlmocP3IuwYEj2j14p8
# ..                                       ...                     ...
# 946                                      Oh!  4e72LGraX8sW5iztJvS5fo
# 947                       God Complex (Mojo)  1B3ouXA9iRkqY1ywvZbzZ5
# 948                                  I EXIST  3eI62ZWWxkl4LUaBqXvA6Y
# 949        Apartment Complex on the Eastside  1cRk9clJhi67mcfTxNfnjU
# 950                      Black Roller Coming  5OLFlnmmC8gQHiFisYvrAh
#
#                                                  Album            Artist  \
# ...

# %%
mood_cleaned = master_mood2.drop(['Name', 'Track_ID', 'Album', 'Artist','Artist_ID','Artist_Genre', 'Explicit', 'Playlist'], axis = 1)
mood_cleaned
# Out:
#      Duration_ms  Popularity  Danceability  Energy  Key  Loudness  Mode  \
# 0         148485          97         0.704   0.797    0    -5.927     1
# 1         167303          96         0.520   0.731    6    -5.338     0
# 2         154486          93         0.881   0.592    2    -4.898     1
# 3         179551          93         0.565   0.636    0    -8.198     1
# 4         163025          93         0.768   0.714   10    -5.110     1
# ..           ...         ...           ...     ...  ...       ...   ...
# 946       155821          48         0.639   0.950    2    -3.313     1
# 947       106740          48         0.573   0.723    6    -3.333     0
# 948       269666          49         0.469   0.882    5    -4.702     1
# 949       247545          41         0.469   0.885    1    -5.433     1
# 950       169287          44         0.400   0.916    9    -5.443     0
#
#      Speechiness  Acousticness  Instrumentalness  Liveness  Valence    Tempo  \
# ...

# %% [markdown]
# ## Removing Outliers
# ### Looking at overall distribution in features and identifying outliers.

# %%
mood_cont = mood_cleaned.drop (['Key', 'Mode', 'MoodR', 'ExplicitR'], axis=1)

# %%
flierprops = dict(marker='o', markersize=5, markeredgecolor='black', markerfacecolor='green', alpha=0.5)
p = sns.boxplot(x= mood_cont['Duration_ms'], palette = "viridis", flierprops=flierprops)
p.set_xlabel('Duration_ms', fontsize= 14, fontweight='bold')
p.set_title('Duration_ms Distribution', fontsize= 16, fontweight='bold');

# %%
from numpy import percentile

q25, q75 = percentile(mood_cont['Duration_ms'], 25), percentile(mood_cont['Duration_ms'], 75)
iqr = q75 - q25

cut_off = iqr*1.5
lower, upper = q25-cut_off, q75 + cut_off

outliers= [x for x in mood_cont['Duration_ms'] if x < lower or x > upper]
len(outliers)
# Out:
# 29

# %%
duration_outliers = master_mood2.loc[mood_cont['Duration_ms'].isin(outliers)]
duration_outliers
# Out:
#                                                   Name  \
# 110                                        Tiny Dancer
# 169             More Than A Woman - SG's Paradise Edit
# 196            The Last Goodbye (feat. Bettye LaVette)
# 201                                               UUUU
# 207                        In Control - Innellea Remix
# 234                                             No Fun
# 237                       Always - Monkey Safari Remix
# 253                                              Ronda
# 255                Light Of Day (feat. Ólafur Arnalds)
# 298                                            La Luna
# 305                                               Just
# 318                                           Soldiner
# 360                        Hope - Parra For Cuva Remix
# 404  All Too Well (10 Minute Version) (Taylor's Ver...
# 459                                       Marvins Room
# 465                                       I Drink Wine
# ...

# %%
flierprops = dict(marker='o', markersize=5, markeredgecolor='black', markerfacecolor='green', alpha=0.5)
p = sns.boxplot(x= mood_cont['Popularity'], palette = "viridis", flierprops=flierprops)
p.set_xlabel('Popularity', fontsize= 14, fontweight='bold')
p.set_title('Popularity Distribution', fontsize= 16, fontweight='bold');

# %%
q25, q75 = percentile(mood_cont['Popularity'], 25), percentile(mood_cont['Popularity'], 75)
iqr = q75 - q25

cut_off = iqr*1.5
lower, upper = q25-cut_off, q75 + cut_off

outliers= [x for x in mood_cont['Popularity'] if x < lower or x > upper]
len(outliers)
# Out:
# 4

# %%
pop_outliers = master_mood2.loc[mood_cont['Popularity'].isin(outliers)]
pop_outliers
# Out:
#                                       Name                Track_ID  \
# 159                            I'm in Love  2k2AJgV5PAA4pIl9jdJxqz
# 865                             What Kinda  6tK23xx5yhFkDKcw0qN66C
# 867                                 Bout U  3QWiUcQwaFsR7a4U1zOKmX
# 870  Think It’s Funny (feat. Babyface Ray)  1mwj7ag32lH1x6nZyFtGPh
#
#            Album       Artist               Artist_ID  \
# 159  I'm in Love   Ted Fresco  2lH1vV1rGOw0ETBmnTAyvZ
# 865  Lebra Jolie  Lebra Jolie  3ej8SuMJzEgwFLe2lCBikV
# 867       Bout U         Kali  1YRqgFNXqRyMDRr8ClS1NL
# 870  Lebra Jolie  Lebra Jolie  3ej8SuMJzEgwFLe2lCBikV
#
#                          Artist_Genre  Duration_ms  Popularity  Explicit  \
# 159                                []       196343           1     False
# 865     ['houston rap', 'trap queen']       181541           0      True
# 867  ['alternative r&b', 'viral rap']       159755          26      True
# ...

# %%
flierprops = dict(marker='o', markersize=5, markeredgecolor='black', markerfacecolor='green', alpha=0.5)
p = sns.boxplot(x= mood_cont['Danceability'], palette = "viridis", flierprops=flierprops)
p.set_xlabel('Danceability', fontsize= 14, fontweight='bold')
p.set_title('Danceability Distribution', fontsize= 16, fontweight='bold');

# %%
q25, q75 = percentile(mood_cont['Danceability'], 25), percentile(mood_cont['Danceability'], 75)
iqr = q75 - q25

cut_off = iqr*1.5
lower, upper = q25-cut_off, q75 + cut_off

outliers= [x for x in mood_cont['Danceability'] if x < lower or x > upper]
len(outliers)
# Out:
# 4

# %%
dance_outliers = master_mood2.loc[mood_cont['Danceability'].isin(outliers)]
dance_outliers
# Out:
#                     Name                Track_ID  \
# 370           Silhouette  5XflWKyyLrg3HlvjlDn6Rk
# 410           All I Want  0NlGoUyOJSuSHmngoibVAs
# 550      Keep Holding On  4UPcXTh26ilb7owtuyHqNI
# 939  Natural Born Killer  4nMUPQeTor23d8RxiiJO9W
#
#                                       Album          Artist  \
# 370                              Silhouette           Yotto
# 410   In A Perfect World (Expanded Edition)        Kodaline
# 550  The Best Damn Thing (Expanded Edition)   Avril Lavigne
# 939                 The Midnight Demon Club  Highly Suspect
#
#                   Artist_ID  \
# 370  5Dyfxq0ZrFjjeFBdSNxDbo
# 410  4BxCuXFJrSWGi1KHcVqaU4
# 550  0p4nmQO2msCgU4IF37Wi3j
# 939  2pqd3HsfsvcBGtHvPOg6eg
#
#                                           Artist_Genre  Duration_ms  \
# 370        ['edm', 'finnish edm', 'progressive house']       213349
# 410         ['irish pop', 'pop', 'pop rock', 'uk pop']       305746
# ...

# %%
flierprops = dict(marker='o', markersize=5, markeredgecolor='black', markerfacecolor='green', alpha=0.5)
p = sns.boxplot(x= mood_cont['Energy'], palette = "viridis", flierprops=flierprops)
p.set_xlabel('Energy', fontsize= 14, fontweight='bold')
p.set_title('Energy Distribution', fontsize= 16, fontweight='bold');

# %%
flierprops = dict(marker='o', markersize=5, markeredgecolor='black', markerfacecolor='green', alpha=0.5)
p = sns.boxplot(x= mood_cont['Loudness'], palette = "viridis", flierprops=flierprops)
p.set_xlabel('Loudness', fontsize= 14, fontweight='bold')
p.set_title('Loudness Distribution', fontsize= 16, fontweight='bold');

# %%
q25, q75 = percentile(mood_cont['Loudness'], 25), percentile(mood_cont['Loudness'], 75)
iqr = q75 - q25

cut_off = iqr*1.5
lower, upper = q25-cut_off, q75 + cut_off

outliers= [x for x in mood_cont['Loudness'] if x < lower or x > upper]
len(outliers)
# Out:
# 27

# %%
loud_outliers = master_mood2.loc[mood_cont['Loudness'].isin(outliers)]
loud_outliers
# Out:
#                                                   Name  \
# 79                                              Africa
# 102                                     Sweet Caroline
# 117                                          Landslide
# 297                                              Bound
# 324                                        Left Behind
# 348                             8 Hours, Still No Rain
# 364                                               Ozon
# 377                             Closed for Renovations
# 412                                     Fourth of July
# 431                                 listen before i go
# 459                                       Marvins Room
# 552                         I Can't Carry This Anymore
# 583                             The Fault in Our Stars
# 682                                 Dreaming My Dreams
# 699                                         i love you
# 707                             Fall in Love with You.
# ...

# %%
flierprops = dict(marker='o', markersize=5, markeredgecolor='black', markerfacecolor='green', alpha=0.5)
p = sns.boxplot(x= mood_cont['Speechiness'], palette = "viridis", flierprops=flierprops)
p.set_xlabel('Speechiness', fontsize= 14, fontweight='bold')
p.set_title('Speechiness Distribution', fontsize= 16, fontweight='bold');

# %%
q25, q75 = percentile(mood_cont['Speechiness'], 25), percentile(mood_cont['Speechiness'], 75)
iqr = q75 - q25

cut_off = iqr*1.5
lower, upper = q25-cut_off, q75 + cut_off

outliers= [x for x in mood_cont['Speechiness'] if x < lower or x > upper]
len(outliers)
# Out:
# 128

# %%
speech_outliers = master_mood2.loc[mood_cont['Speechiness'].isin(outliers)]
speech_outliers
# Out:
#                         Name                Track_ID  \
# 16         THATS WHAT I WANT  0e8nrvls4Qqv5Rfa2UhqmO
# 27              Light Switch  1BSMpVGWs3v5BZKnAQziAc
# 46                      Lost  18XlJEroUwFo0tLZxscgXE
# 69                       Joy  4Hn4zAkBUaNnT8m9p7cYaf
# 78        I'm Still Standing  1jDJFeK9x3OZboIAHsY9k2
# ..                       ...                     ...
# 929                  Babylon  0JlNtj7KalsjE4MWnwfv3U
# 930        What's the Trick?  14FW5L81Px03LnnsXnB2LG
# 937  Who’s Gonna Love Me Now  1T9DxFAS1H7RgR4PDUzAGQ
# 938                  Puzzles  0rWIAbUoOL67JAHxxGRKx7
# 939      Natural Born Killer  4nMUPQeTor23d8RxiiJO9W
#
#                         Album          Artist               Artist_ID  \
# 16                    MONTERO       Lil Nas X  7jVv8c5Fj3E9VhNjxT4snq
# 27               Light Switch    Charlie Puth  6VuMaDnrHyPL1p4EHjYLi7
# 46             JORDI (Deluxe)        Maroon 5  04gDigrS5kc9YWfZHwBETP
# ...

# %%
flierprops = dict(marker='o', markersize=5, markeredgecolor='black', markerfacecolor='green', alpha=0.5)
p = sns.boxplot(x= mood_cont['Acousticness'], palette = "viridis", flierprops=flierprops)
p.set_xlabel('Acousticness', fontsize= 14, fontweight='bold')
p.set_title('Acousticness Distribution', fontsize= 16, fontweight='bold');

# %%
flierprops = dict(marker='o', markersize=5, markeredgecolor='black', markerfacecolor='green', alpha=0.5)
p = sns.boxplot(x= mood_cont['Instrumentalness'], palette = "viridis", flierprops=flierprops)
p.set_xlabel('Instrumentalness', fontsize= 14, fontweight='bold')
p.set_title('Instrumentalness Distribution', fontsize= 16, fontweight='bold');

# %%
q25, q75 = percentile(mood_cont['Instrumentalness'], 25), percentile(mood_cont['Instrumentalness'], 75)
iqr = q75 - q25

cut_off = iqr*1.5
lower, upper = q25-cut_off, q75 + cut_off

outliers= [x for x in mood_cont['Instrumentalness'] if x < lower or x > upper]
len(outliers)
# Out:
# 206

# %%
instr_outliers = master_mood2.loc[mood_cont['Instrumentalness'].isin(outliers)]
instr_outliers
# Out:
#                                        Name                Track_ID  \
# 97                      Walking On Sunshine  05wIrZSwuaVWhcv5FfqeH0
# 151                                 Alright  5xC8uOesnn0udeXAYlAnoY
# 156                             Happy Music  3rh495Z2rIRwD316blea4f
# 160                Sunshine (feat. Fousheé)  0mRbKcvmbbUtfFyfeFHCJa
# 169  More Than A Woman - SG's Paradise Edit  0L3XCv9i9IHs8cJEVhsJ3J
# ..                                      ...                     ...
# 916                                Elephant  6qZjm61s6u8Ead9sWxCDro
# 921                             Boilermaker  6Ci6L6EeLqR6VHV1DBJy2S
# 944                                   Smile  0wQKKPy050lguUxlKvHIi5
# 946                                     Oh!  4e72LGraX8sW5iztJvS5fo
# 947                      God Complex (Mojo)  1B3ouXA9iRkqY1ywvZbzZ5
#
#                                       Album               Artist  \
# 97                      Katrina & The Waves  Katrina & The Waves
# ...

# %%
flierprops = dict(marker='o', markersize=5, markeredgecolor='black', markerfacecolor='green', alpha=0.5)
p = sns.boxplot(x= mood_cont['Liveness'], palette = "viridis", flierprops=flierprops)
p.set_xlabel('Liveness', fontsize= 14, fontweight='bold')
p.set_title('Liveness Distribution', fontsize= 16, fontweight='bold');

# %%
q25, q75 = percentile(mood_cont['Liveness'], 25), percentile(mood_cont['Liveness'], 75)
iqr = q75 - q25

cut_off = iqr*1.5
lower, upper = q25-cut_off, q75 + cut_off

outliers= [x for x in mood_cont['Liveness'] if x < lower or x > upper]
len(outliers)
# Out:
# 117

# %%
live_outliers = master_mood2.loc[mood_cont['Liveness'].isin(outliers)]
live_outliers
# Out:
#                                   Name                Track_ID  \
# 1                            As It Was  4LRPiXqCikLlN15c3yImP7
# 3                                 SNAP  76OGwb5RA9h4FxQPT33ekc
# 7                      About Damn Time  1PckUlxKqWQs3RlWXVBLw3
# 15          Bam Bam (feat. Ed Sheeran)  0QBzMgT7NIeoCYy3sJCof1
# 18                    Watermelon Sugar  6UelLqGlWMcVH1E5c4H7lY
# ..                                 ...                     ...
# 940                  ILY, HOW ARE YOU?  51sGd4PYmBWbVNMCAh3nd0
# 945                 Ready for the High  1v7w94vaYr1gcVUkIgN7y1
# 947                 God Complex (Mojo)  1B3ouXA9iRkqY1ywvZbzZ5
# 948                            I EXIST  3eI62ZWWxkl4LUaBqXvA6Y
# 949  Apartment Complex on the Eastside  1cRk9clJhi67mcfTxNfnjU
#
#                             Album          Artist               Artist_ID  \
# 1                       As It Was    Harry Styles  6KImCVD70vtIoJWnq6nGn3
# ...

# %%
flierprops = dict(marker='o', markersize=5, markeredgecolor='black', markerfacecolor='green', alpha=0.5)
p = sns.boxplot(x= mood_cont['Valence'], palette = "viridis", flierprops=flierprops)
p.set_xlabel('Valence', fontsize= 14, fontweight='bold')
p.set_title('Valence Distribution', fontsize= 16, fontweight='bold');

# %%
flierprops = dict(marker='o', markersize=5, markeredgecolor='black', markerfacecolor='green', alpha=0.5)
p = sns.boxplot(x= mood_cont['Tempo'], palette = "viridis", flierprops=flierprops)
p.set_xlabel('Tempo', fontsize= 14, fontweight='bold')
p.set_title('Tempo Distribution', fontsize= 16, fontweight='bold');

# %%
q25, q75 = percentile(mood_cont['Tempo'], 25), percentile(mood_cont['Tempo'], 75)
iqr = q75 - q25

cut_off = iqr*1.5
lower, upper = q25-cut_off, q75 + cut_off

outliers= [x for x in mood_cont['Tempo'] if x < lower or x > upper]
len(outliers)
# Out:
# 20

# %%
master_mood2.loc[mood_cleaned['Tempo'] < 60]
# Out:
#                  Name                Track_ID      Album   Artist  \
# 522  Superficial Love  5hwh37sTi84MVhCBMWzhGE  The Intro  Ruth B.
#
#                   Artist_ID  \
# 522  2WzaAvm2bBCf4pEhyuDgCY
#
#                                           Artist_Genre  Duration_ms  \
# 522  ['alt z', 'canadian contemporary r&b', 'canadi...       207973
#
#      Popularity  Explicit  Danceability  ...  Speechiness  Acousticness  \
# 522          68     False         0.477  ...       0.0529         0.928
#
#      Instrumentalness  Liveness  Valence   Tempo    Playlist  Mood  MoodR  \
# 522               0.0    0.0818    0.488  43.509  Life_Sucks   Sad      3
#
#      ExplicitR
# 522          0
#
# [1 rows x 24 columns]

# %% [markdown]
# #### I definitely don't think this song has the right bpm. I think it's more around 75 than 43.5 (which is soooo slow).

# %%
tempo_outliers = master_mood2.loc[mood_cont['Tempo'].isin(outliers)]
tempo_outliers
# Out:
#                                      Name                Track_ID  \
# 27                           Light Switch  1BSMpVGWs3v5BZKnAQziAc
# 119                                   One  3G69vJMWsX6ZohTykad2AU
# 185                     That's Where I Am  4f1KkbXHnfIVZ9vmIExByJ
# 204                             Breathing  1MvLmHeLkaNgUScgbUVnWJ
# 228                               Survive  5QZdeEHEHy1Jphbral0nbv
# 303                    Something Was Real  7HXqYIF5kMN1XY52GWQKrZ
# 308                             Entangled  2OISrK95L88giQdFHurbfY
# 338                             The Chase  44j2camBItOSBgDTWAEZaZ
# 410                            All I Want  0NlGoUyOJSuSHmngoibVAs
# 522                      Superficial Love  5hwh37sTi84MVhCBMWzhGE
# 572                        Never Be Alone  4LWIp8HAFxpfg37mnxHqCS
# 597                               I Found  4lRuRtvftdSSUA7hLP7zAr
# 612                     Until I Found You  6VhuP99TE6gYNQRJIlAWFD
# ...

# %% [markdown]
# ### Combining outliers

# %%
all_out = pd.concat([duration_outliers, pop_outliers, dance_outliers, loud_outliers, speech_outliers, instr_outliers, live_outliers, tempo_outliers])
all_out
# Out:
#                                         Name                Track_ID  \
# 110                              Tiny Dancer  2TVxnKdb3tqe1nhQWwwZCO
# 169   More Than A Woman - SG's Paradise Edit  0L3XCv9i9IHs8cJEVhsJ3J
# 196  The Last Goodbye (feat. Bettye LaVette)  4XeIiGpUBshIfs9yrBDVZC
# 201                                     UUUU  46OIVHWlExMXlqYRCpkEYd
# 207              In Control - Innellea Remix  35fdRgZrz5ujDGBaqhoPE8
# ..                                       ...                     ...
# 647                                    Gooey  1gk3FhAV07q9Jg77UxnVjX
# 692                                  On Call  28POcTYQKfkjz6qTIvtjG1
# 860                                So Pretty  1yLTcitjbEJr7a4jyDB0Lz
# 929                                  Babylon  0JlNtj7KalsjE4MWnwfv3U
# 939                      Natural Born Killer  4nMUPQeTor23d8RxiiJO9W
#
#                                        Album          Artist  \
# 110                  Madman Across The Water      Elton John
# ...

# %%
all_out2 = all_out.drop_duplicates(subset=['Track_ID'], keep='first')
all_out2
# Out:
#                                         Name                Track_ID  \
# 110                              Tiny Dancer  2TVxnKdb3tqe1nhQWwwZCO
# 169   More Than A Woman - SG's Paradise Edit  0L3XCv9i9IHs8cJEVhsJ3J
# 196  The Last Goodbye (feat. Bettye LaVette)  4XeIiGpUBshIfs9yrBDVZC
# 201                                     UUUU  46OIVHWlExMXlqYRCpkEYd
# 207              In Control - Innellea Remix  35fdRgZrz5ujDGBaqhoPE8
# ..                                       ...                     ...
# 572                           Never Be Alone  4LWIp8HAFxpfg37mnxHqCS
# 597                                  I Found  4lRuRtvftdSSUA7hLP7zAr
# 612                        Until I Found You  6VhuP99TE6gYNQRJIlAWFD
# 633                                   Cherry  2HQY0sXTrBJCuxqJxbeMWB
# 647                                    Gooey  1gk3FhAV07q9Jg77UxnVjX
#
#                                         Album           Artist  \
# 110                   Madman Across The Water       Elton John
# ...

# %%
df_no_out = master_mood2.loc[-master_mood2['Track_ID'].isin(all_out2['Track_ID'])]
df_no_out
# Out:
#                                             Name                Track_ID  \
# 0                                I Ain't Worried  4h9wh7iOZ0GGn8QVp4RAOB
# 2        Left and Right (Feat. Jung Kook of BTS)  0mBP9X2gPCuapvpZ7TGDk3
# 4                                        Sunroof  4h4QlmocP3IuwYEj2j14p8
# 5    I Like You (A Happier Song) (with Doja Cat)  0O6u0VJ46W86TxN9wgyqDj
# 6                                     Dandelions  2eAvDnpXP5W0cVtiI0PUxV
# ..                                           ...                     ...
# 936                                     I.N.V.U.  6qTagiSQjEcfpVm1NHJJEU
# 941           Fuck Me (I Didn’t Know How To Say)  07M8tCNuO9RZenyINtp2QB
# 942                                 THREE HEADS*  4apXjryIqMFUdOjWMM6zZp
# 943                               What Went Down  78tgXRq9Q6tPNP9hKCpgwB
# 950                          Black Roller Coming  5OLFlnmmC8gQHiFisYvrAh
#
#                                                  Album        Artist  \
# ...

# %%
print(len(df_no_out.loc[df_no_out['Mood'] == "Happy"]))
print(len(df_no_out.loc[df_no_out['Mood'] == "Chill"]))
print(len(df_no_out.loc[df_no_out['Mood'] == "Sad"]))
print(len(df_no_out.loc[df_no_out['Mood'] == "Romance"]))
print(len(df_no_out.loc[df_no_out['Mood'] == "Confidence"]))
# Out:
# 144
# 37
# 160
# 123
# 49

# %% [markdown]
# ### Removing the outliers takes both chill and confidence down to a pretty small count.

# %%
df_no_out.to_csv('mood_no_out.csv')

# %% [markdown]
# ### Also making a dataframe with just the extreme outliers removed, since with all of them removed it takes the data set down to 513 songs only.

# %%
dur_ex = master_mood2.loc[mood_cleaned['Duration_ms']  >= 500000]
loud_ex = master_mood2.loc[mood_cleaned['Loudness'] <= -25]
speech_ex = master_mood2.loc[mood_cleaned['Speechiness'] > .5]
temp_ex = master_mood2.loc[mood_cleaned['Tempo'] < 45]

# %%
out_ex = pd.concat([dur_ex, loud_ex, speech_ex, temp_ex, pop_outliers, dance_outliers])
out_ex
# Out:
#                                                   Name  \
# 404  All Too Well (10 Minute Version) (Taylor's Ver...
# 733                                         Avril 14th
# 422                                            Flowers
# 522                                   Superficial Love
# 159                                        I'm in Love
# 865                                         What Kinda
# 867                                             Bout U
# 870              Think It’s Funny (feat. Babyface Ray)
# 370                                         Silhouette
# 410                                         All I Want
# 550                                    Keep Holding On
# 939                                Natural Born Killer
#
#                    Track_ID                                   Album  \
# 404  5enxwA8aAbwZbf5qCHORXi                  Red (Taylor's Version)
# 733  2MZSXhq4XDJWu6coGoXX1V                                  Drukqs
# ...

# %%
mood_no_ex = master_mood2.loc[-master_mood2['Track_ID'].isin(out_ex['Track_ID'])]
mood_no_ex
# Out:
#                                         Name                Track_ID  \
# 0                            I Ain't Worried  4h9wh7iOZ0GGn8QVp4RAOB
# 1                                  As It Was  4LRPiXqCikLlN15c3yImP7
# 2    Left and Right (Feat. Jung Kook of BTS)  0mBP9X2gPCuapvpZ7TGDk3
# 3                                       SNAP  76OGwb5RA9h4FxQPT33ekc
# 4                                    Sunroof  4h4QlmocP3IuwYEj2j14p8
# ..                                       ...                     ...
# 946                                      Oh!  4e72LGraX8sW5iztJvS5fo
# 947                       God Complex (Mojo)  1B3ouXA9iRkqY1ywvZbzZ5
# 948                                  I EXIST  3eI62ZWWxkl4LUaBqXvA6Y
# 949        Apartment Complex on the Eastside  1cRk9clJhi67mcfTxNfnjU
# 950                      Black Roller Coming  5OLFlnmmC8gQHiFisYvrAh
#
#                                                  Album            Artist  \
# ...

# %%
mood_no_ex.to_csv('mood_no_ex.csv')
